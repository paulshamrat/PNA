# %% [markdown]
# ## Downloading PDB Files Using Biopython
#
# This notebook demonstrates how to download a list of unique PDB files using Biopython.
#
# ### Steps:
# 1. Install Biopython.
# 2. Use Biopython's `PDBList` module to download each PDB file from the RCSB PDB database.

# %%
# List of unique PDB IDs
pdb_ids = ['6ki6', '6kbs', '5zvb', '5zva', '5xs0', '5ke6', '5ed4', '5co8', 
           '4yg4', '4x23', '4wcg', '4qtk', '4qju', '4nm6', '4m9e', '4lll', 
           '4ljr', '4l0z', '4kmf', '4k4g', '4hqb', '4hn5', '4gzn', '4ch1', 
           '4bnc', '3wpd', '3wpc', '3qi5', '3ode', '3od8', '3mx9', '3gqc', 
           '3bs1', '2vs7', '2vla', '2qby', '2moe', '2i05', '1w7a', '1qzg', 
           '1qbj', '1pvi', '1puf', '1par', '1mse', '1lmb', '1k82', '1j5n', 
           '1io4', '1g9z', '1az0']

# %%
# Install Biopython (if not already installed)
# !pip install biopython
# Out:
# Requirement already satisfied: biopython in c:\users\paul\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.79)
# Requirement already satisfied: numpy in c:\users\paul\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from biopython) (1.23.5)
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: C:\Users\paul\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from Bio.PDB import PDBList

# Initialize PDBList
pdb_list = PDBList()

# Download each PDB file
for pdb_id in pdb_ids:
    pdb_list.retrieve_pdb_file(pdb_id, file_format='pdb', pdir='pdb_files')
# Out:
# Downloading PDB structure '6ki6'...
# Downloading PDB structure '6kbs'...
# Downloading PDB structure '5zvb'...
# Downloading PDB structure '5zva'...
# Downloading PDB structure '5xs0'...
# Downloading PDB structure '5ke6'...
# Downloading PDB structure '5ed4'...
# Downloading PDB structure '5co8'...
# Downloading PDB structure '4yg4'...
# Downloading PDB structure '4x23'...
# Downloading PDB structure '4wcg'...
# Downloading PDB structure '4qtk'...
# Downloading PDB structure '4qju'...
# Downloading PDB structure '4nm6'...
# Downloading PDB structure '4m9e'...
# Downloading PDB structure '4lll'...
# Downloading PDB structure '4ljr'...
# Downloading PDB structure '4l0z'...
# Downloading PDB structure '4kmf'...
# Downloading PDB structure '4k4g'...
# Downloading PDB structure '4hqb'...
# Downloading PDB structure '4hn5'...
# Downloading PDB structure '4gzn'...
# Downloading PDB structure '4ch1'...
# Downloading PDB structure '4bnc'...
# Downloading PDB structure '3wpd'...
# Downloading PDB structure '3wpc'...
# Downloading PDB structure '3qi5'...
# Downloading PDB structure '3ode'...
# Downloading PDB structure '3od8'...
# Downloading PDB structure '3mx9'...
# Downloading PDB structure '3gqc'...
# Downloading PDB structure '3bs1'...
# Downloading PDB structure '2vs7'...
# Downloading PDB structure '2vla'...
# Downloading PDB structure '2qby'...
# Downloading PDB structure '2moe'...
# Downloading PDB structure '2i05'...
# Downloading PDB structure '1w7a'...
# Downloading PDB structure '1qzg'...
# Downloading PDB structure '1qbj'...
# Downloading PDB structure '1pvi'...
# Downloading PDB structure '1puf'...
# Downloading PDB structure '1par'...
# Downloading PDB structure '1mse'...
# Downloading PDB structure '1lmb'...
# Downloading PDB structure '1k82'...
# Downloading PDB structure '1j5n'...
# Downloading PDB structure '1io4'...
# Downloading PDB structure '1g9z'...
# Downloading PDB structure '1az0'...

# %% [markdown]
# # CONVERT ENT TO PDB

# %%
from Bio.PDB import PDBList
import os

# Initialize PDBList
pdb_list = PDBList()

# Directory to save the PDB files
save_dir = 'pdb_files'

# Create the directory if it doesn't exist
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Download each PDB file
for pdb_id in pdb_ids:
    # Download in pdb format
    pdb_file = pdb_list.retrieve_pdb_file(pdb_id, file_format='pdb', pdir=save_dir)
    
    # Rename .ent file to .pdb if necessary
    if pdb_file.endswith('.ent'):
        new_name = os.path.join(save_dir, f'{pdb_id}.pdb')
        os.rename(pdb_file, new_name)
        print(f'Renamed {pdb_file} to {new_name}')
    else:
        print(f'{pdb_file} is already in PDB format')
# Out:
# Structure exists: 'pdb_files\pdb6ki6.ent'
# Renamed pdb_files\pdb6ki6.ent to pdb_files\6ki6.pdb
# Structure exists: 'pdb_files\pdb6kbs.ent'
# Renamed pdb_files\pdb6kbs.ent to pdb_files\6kbs.pdb
# Structure exists: 'pdb_files\pdb5zvb.ent'
# Renamed pdb_files\pdb5zvb.ent to pdb_files\5zvb.pdb
# Structure exists: 'pdb_files\pdb5zva.ent'
# Renamed pdb_files\pdb5zva.ent to pdb_files\5zva.pdb
# Structure exists: 'pdb_files\pdb5xs0.ent'
# Renamed pdb_files\pdb5xs0.ent to pdb_files\5xs0.pdb
# Structure exists: 'pdb_files\pdb5ke6.ent'
# Renamed pdb_files\pdb5ke6.ent to pdb_files\5ke6.pdb
# Structure exists: 'pdb_files\pdb5ed4.ent'
# Renamed pdb_files\pdb5ed4.ent to pdb_files\5ed4.pdb
# Structure exists: 'pdb_files\pdb5co8.ent'
# Renamed pdb_files\pdb5co8.ent to pdb_files\5co8.pdb
# Structure exists: 'pdb_files\pdb4yg4.ent'
# Renamed pdb_files\pdb4yg4.ent to pdb_files\4yg4.pdb
# Structure exists: 'pdb_files\pdb4x23.ent'
# Renamed pdb_files\pdb4x23.ent to pdb_files\4x23.pdb
# Structure exists: 'pdb_files\pdb4wcg.ent'
# Renamed pdb_files\pdb4wcg.ent to pdb_files\4wcg.pdb
# Structure exists: 'pdb_files\pdb4qtk.ent'
# Renamed pdb_files\pdb4qtk.ent to pdb_files\4qtk.pdb
# Structure exists: 'pdb_files\pdb4qju.ent'
# Renamed pdb_files\pdb4qju.ent to pdb_files\4qju.pdb
# Structure exists: 'pdb_files\pdb4nm6.ent'
# Renamed pdb_files\pdb4nm6.ent to pdb_files\4nm6.pdb
# Structure exists: 'pdb_files\pdb4m9e.ent'
# Renamed pdb_files\pdb4m9e.ent to pdb_files\4m9e.pdb
# Structure exists: 'pdb_files\pdb4lll.ent'
# Renamed pdb_files\pdb4lll.ent to pdb_files\4lll.pdb
# Structure exists: 'pdb_files\pdb4ljr.ent'
# Renamed pdb_files\pdb4ljr.ent to pdb_files\4ljr.pdb
# Structure exists: 'pdb_files\pdb4l0z.ent'
# Renamed pdb_files\pdb4l0z.ent to pdb_files\4l0z.pdb
# Structure exists: 'pdb_files\pdb4kmf.ent'
# Renamed pdb_files\pdb4kmf.ent to pdb_files\4kmf.pdb
# Structure exists: 'pdb_files\pdb4k4g.ent'
# Renamed pdb_files\pdb4k4g.ent to pdb_files\4k4g.pdb
# Structure exists: 'pdb_files\pdb4hqb.ent'
# Renamed pdb_files\pdb4hqb.ent to pdb_files\4hqb.pdb
# Structure exists: 'pdb_files\pdb4hn5.ent'
# Renamed pdb_files\pdb4hn5.ent to pdb_files\4hn5.pdb
# Structure exists: 'pdb_files\pdb4gzn.ent'
# Renamed pdb_files\pdb4gzn.ent to pdb_files\4gzn.pdb
# Structure exists: 'pdb_files\pdb4ch1.ent'
# Renamed pdb_files\pdb4ch1.ent to pdb_files\4ch1.pdb
# Structure exists: 'pdb_files\pdb4bnc.ent'
# Renamed pdb_files\pdb4bnc.ent to pdb_files\4bnc.pdb
# Structure exists: 'pdb_files\pdb3wpd.ent'
# Renamed pdb_files\pdb3wpd.ent to pdb_files\3wpd.pdb
# Structure exists: 'pdb_files\pdb3wpc.ent'
# Renamed pdb_files\pdb3wpc.ent to pdb_files\3wpc.pdb
# Structure exists: 'pdb_files\pdb3qi5.ent'
# Renamed pdb_files\pdb3qi5.ent to pdb_files\3qi5.pdb
# Structure exists: 'pdb_files\pdb3ode.ent'
# Renamed pdb_files\pdb3ode.ent to pdb_files\3ode.pdb
# Structure exists: 'pdb_files\pdb3od8.ent'
# Renamed pdb_files\pdb3od8.ent to pdb_files\3od8.pdb
# Structure exists: 'pdb_files\pdb3mx9.ent'
# Renamed pdb_files\pdb3mx9.ent to pdb_files\3mx9.pdb
# Structure exists: 'pdb_files\pdb3gqc.ent'
# Renamed pdb_files\pdb3gqc.ent to pdb_files\3gqc.pdb
# Structure exists: 'pdb_files\pdb3bs1.ent'
# Renamed pdb_files\pdb3bs1.ent to pdb_files\3bs1.pdb
# Structure exists: 'pdb_files\pdb2vs7.ent'
# Renamed pdb_files\pdb2vs7.ent to pdb_files\2vs7.pdb
# Structure exists: 'pdb_files\pdb2vla.ent'
# Renamed pdb_files\pdb2vla.ent to pdb_files\2vla.pdb
# Structure exists: 'pdb_files\pdb2qby.ent'
# Renamed pdb_files\pdb2qby.ent to pdb_files\2qby.pdb
# Structure exists: 'pdb_files\pdb2moe.ent'
# Renamed pdb_files\pdb2moe.ent to pdb_files\2moe.pdb
# Structure exists: 'pdb_files\pdb2i05.ent'
# Renamed pdb_files\pdb2i05.ent to pdb_files\2i05.pdb
# Structure exists: 'pdb_files\pdb1w7a.ent'
# Renamed pdb_files\pdb1w7a.ent to pdb_files\1w7a.pdb
# Structure exists: 'pdb_files\pdb1qzg.ent'
# Renamed pdb_files\pdb1qzg.ent to pdb_files\1qzg.pdb
# Structure exists: 'pdb_files\pdb1qbj.ent'
# Renamed pdb_files\pdb1qbj.ent to pdb_files\1qbj.pdb
# Structure exists: 'pdb_files\pdb1pvi.ent'
# Renamed pdb_files\pdb1pvi.ent to pdb_files\1pvi.pdb
# Structure exists: 'pdb_files\pdb1puf.ent'
# Renamed pdb_files\pdb1puf.ent to pdb_files\1puf.pdb
# Structure exists: 'pdb_files\pdb1par.ent'
# Renamed pdb_files\pdb1par.ent to pdb_files\1par.pdb
# Structure exists: 'pdb_files\pdb1mse.ent'
# Renamed pdb_files\pdb1mse.ent to pdb_files\1mse.pdb
# Structure exists: 'pdb_files\pdb1lmb.ent'
# Renamed pdb_files\pdb1lmb.ent to pdb_files\1lmb.pdb
# Structure exists: 'pdb_files\pdb1k82.ent'
# Renamed pdb_files\pdb1k82.ent to pdb_files\1k82.pdb
# Structure exists: 'pdb_files\pdb1j5n.ent'
# Renamed pdb_files\pdb1j5n.ent to pdb_files\1j5n.pdb
# Structure exists: 'pdb_files\pdb1io4.ent'
# Renamed pdb_files\pdb1io4.ent to pdb_files\1io4.pdb
# Structure exists: 'pdb_files\pdb1g9z.ent'
# Renamed pdb_files\pdb1g9z.ent to pdb_files\1g9z.pdb
# Structure exists: 'pdb_files\pdb1az0.ent'
# Renamed pdb_files\pdb1az0.ent to pdb_files\1az0.pdb
